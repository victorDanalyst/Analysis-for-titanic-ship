# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
titanic_df = pd.read_csv(r"C:\Users\victor\Desktop\Data analysis\titanic python.csv")

titanic_df.head(40)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
# 20          912         0       1
# 21          913         0       3
# 22          914         1       1
# 23          915         0       1
# 24          916         1       1
# 25          917         0       3
# ...

# %%
titanic_df[["Age" ]].plot()

# from the graph we can tell that the oldest passenger was about 70 yrs old
# Out:
# <AxesSubplot:>

# %%
titanic_df[["PassengerId"]].plot()


# They
# Out:
# <AxesSubplot:>

# %%
titanic_df.iloc[0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
## titanic_df.loc[titanic_df["Embarked"] == "Q"]


# titanic_df.to_excel("modified analysis 1.0 for titanic.xlsx" , index=False)

# %%
titanic_df.loc[titanic_df["Sex"] == "female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
titanic_df.plot.scatter(x="Age" y="Pclass", alpha=0.5)
# Out:
#   File "<ipython-input-12-2e0dfb9336ad>", line 1
#     titanic_df.plot.scatter(x="Age" y="Pclass", alpha=0.5)
#                                     ^
# SyntaxError: invalid syntax

# %%
titanic_df[["Sex"]].iloc[3:12]
# Out:
#        Sex
# 3     male
# 4   female
# 5     male
# 6   female
# 7     male
# 8   female
# 9     male
# 10    male
# 11    male

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
titanic_df.PassengerId.iloc[2:16]
# Out:
# 2     894
# 3     895
# 4     896
# 5     897
# 6     898
# 7     899
# 8     900
# 9     901
# 10    902
# 11    903
# 12    904
# 13    905
# 14    906
# 15    907
# Name: PassengerId, dtype: int64

# %%
titanic_df[["Age"]].iloc[4:10]
# Out:
#     Age
# 4  22.0
# 5  14.0
# 6  30.0
# 7  26.0
# 8  18.0
# 9  21.0

# %%
titanic_df[["Age"]].max()
# Out:
# Age    76.0
# dtype: float64

# %%
titanic_df[["Survived"]].sum()
# Out:
# Survived    152
# dtype: int64

# %%
Above_35_and_notsurvived = titanic_df.loc[(titanic_df["Survived"] == 0) & (titanic_df["Age"]> 35)][["Age"]].count()


Above_35_and_notsurvived
# Out:
# Age    64
# dtype: int64

# %%
[
method_name
 for method_name in dir(titanic_df.plot)
 if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
above_35 = titanic_df.loc[titanic_df["Age"] > 35]

above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 2            894         0       2
# 11           903         0       1
# 13           905         0       2
# 14           906         1       1
# ..           ...       ...     ...
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
# 415         1307         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.loc[titanic_df["Survived"] == 1].count()


#titanic_df.to_excel("survived passenger.xlsx")
# Out:
# PassengerId    152
# Survived       152
# Pclass         152
# Name           152
# Sex            152
# Age            127
# SibSp          152
# Parch          152
# Ticket         152
# Fare           152
# Cabin           44
# Embarked       152
# dtype: int64

# %%
titanic_df[["Survived"]]
# Out:
#      Survived
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ..        ...
# 413         0
# 414         1
# 415         0
# 416         0
# 417         0
#
# [418 rows x 1 columns]

# %%
titanic_df[["Survived"]].head()
# Out:
#    Survived
# 0         0
# 1         1
# 2         0
# 3         0
# 4         1

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic_df.iloc[0:3]
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
titanic_df.loc[titanic_df["Survived"]== 1 ].head(21)
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 4           896         1       3
# 6           898         1       3
# 8           900         1       3
# 12          904         1       1
# 14          906         1       1
# 15          907         1       2
# 18          910         1       3
# 19          911         1       3
# 22          914         1       1
# 24          916         1       1
# 26          918         1       1
# 32          924         1       3
# 33          925         1       3
# 36          928         1       3
# 37          929         1       3
# 43          935         1       2
# 44          936         1       1
# 48          940         1       1
# 49          941         1       3
# 52          944         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# ...

# %%
titanic_df[["Name","Age"]].iloc[0:10]
# Out:
#                                            Name   Age
# 0                              Kelly, Mr. James  34.5
# 1              Wilkes, Mrs. James (Ellen Needs)  47.0
# 2                     Myles, Mr. Thomas Francis  62.0
# 3                              Wirz, Mr. Albert  27.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# 5                    Svensson, Mr. Johan Cervin  14.0
# 6                          Connolly, Miss. Kate  30.0
# 7                  Caldwell, Mr. Albert Francis  26.0
# 8     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  18.0
# 9                       Davies, Mr. John Samuel  21.0

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_df.shape
# Out:
# (418, 12)

# %%
titanic_df.loc[(titanic_df["Fare"] == 7.000) & (titanic_df["Pclass"] == 3)]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 1            893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 163         1055         0       3                Pearce, Mr. Ernest    male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 1    47.0      1      0  363272   7.0   NaN        S
# 163   NaN      0      0  343271   7.0   NaN        S
